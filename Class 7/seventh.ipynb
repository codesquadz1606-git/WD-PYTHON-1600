# %% [markdown]
# String : String is a set of characters in "" is known as string.It is immuteable(non-changeable).It is based on zero based indexing.

# %%
username="Ayush123"
print(type(username))
print(len(username))
print(username[0])
print(username[1])

# username="Neha"
# print(username)
# Out:
# <class 'str'>
# 8
# A
# y

# %%
for i in range(len(username)):
    print(i,username[i])
# Out:
# 0 A
# 1 y
# 2 u
# 3 s
# 4 h
# 5 1
# 6 2
# 7 3

# %%
user="Sarthak"
# user[0]="A" # this is not allowed
user="Ayush"
print(user)
# Out:
# Ayush

# %% [markdown]
# String Methods
# startsWith
# endsWith
# lower
# upper
# title
# swapcase
# strip : lstrip , rstrip
# replace
# find
# count
# split
# join

# %%
name="A-n-k-i-t- -R-a-j-p-u-t"
# print(name.startswith("K")) # true ya false
# print(name.endswith("t"))
# print(name.lower())
# print(name.upper())
# print(name.title())
# print(name.swapcase())
# print(name.strip())
# print(name.lstrip())
# print(name.rstrip())

# print(name.replace("Rajput","Singh"))
# print(name.find("t")) # finds the first occurence.
# print(name.count("t"))

# split : converts string to list
# print(name.split("-"))
# newL=name.split("-")
# print(newL)

# li=["101","Sumit","Java"]
# n="-"
# print(n.join(li))


# Slicing
text1="Ayush Kumar Srivastava"
print(text1[0:7:2]) # [stat:end-1:step]
# Out:
# AuhK
